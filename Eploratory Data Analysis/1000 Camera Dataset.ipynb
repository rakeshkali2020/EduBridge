# %% [markdown]
# # The Camera Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style

import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Reading the Dataset

# %%
df = pd.read_csv("C:/Users/aroha/camera.csv")
temp = pd.DataFrame(df)
temp
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %% [markdown]
# ## To know the number of Rows and Columns

# %%
df.shape
# Out:
# (1038, 13)

# %% [markdown]
# ## To print all the columns name

# %%
df.columns
# Out:
# Index(['Model', 'Release date', 'Max resolution', 'Low resolution',
#        'Effective pixels', 'Zoom wide (W)', 'Zoom tele (T)',
#        'Normal focus range', 'Macro focus range', 'Storage included',
#        'Weight (inc. batteries)', 'Dimensions', 'Price'],
#       dtype='object')

# %% [markdown]
# ## To see if there is any Null values

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                        Model  Release date  Max resolution  Low resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          1
# Storage included           2
# Weight (inc. batteries)    2
# Dimensions                 2
# Price                      0
# dtype: int64

# %% [markdown]
# ## To see the top 10 rows from the sample dataset

# %%
df.head(10)
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997          1024.0           640.0
# 1        Agfa ePhoto 1680          1998          1280.0           640.0
# 2        Agfa ePhoto CL18          2000           640.0             0.0
# 3        Agfa ePhoto CL30          1999          1152.0           640.0
# 4  Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# 5        Agfa ePhoto CL45          2001          1600.0           640.0
# 6        Agfa ePhoto CL50          1999          1280.0           640.0
# 7     Canon PowerShot 350          1997           640.0             0.0
# 8     Canon PowerShot 600          1996           832.0           640.0
# 9     Canon PowerShot A10          2001          1280.0          1024.0
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0               0.0           38.0          114.0                70.0
# ...

# %% [markdown]
# ## To see the last 10 rows from the sample dataset

# %%
df.tail(10)
# Out:
#                 Model  Release date  Max resolution  Low resolution  \
# 1028   Toshiba PDR-M3          1999          1280.0           640.0
# 1029   Toshiba PDR-M4          1999          1600.0           800.0
# 1030   Toshiba PDR-M5          1999          1600.0           800.0
# 1031  Toshiba PDR-M60          2000          1792.0           896.0
# 1032  Toshiba PDR-M61          2001          1792.0           896.0
# 1033  Toshiba PDR-M65          2001          2048.0          1024.0
# 1034  Toshiba PDR-M70          2000          2048.0          1024.0
# 1035  Toshiba PDR-M71          2001          2048.0          1024.0
# 1036  Toshiba PDR-M81          2001          2400.0          1200.0
# 1037  Toshiba PDR-T10          2002          1600.0           800.0
#
#       Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 1028               1.0           38.0          115.0                90.0
# ...

# %% [markdown]
# ## Print the information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model                    1038 non-null   object
#  1   Release date             1038 non-null   int64
#  2   Max resolution           1038 non-null   float64
#  3   Low resolution           1038 non-null   float64
#  4   Effective pixels         1038 non-null   float64
#  5   Zoom wide (W)            1038 non-null   float64
#  6   Zoom tele (T)            1038 non-null   float64
#  7   Normal focus range       1038 non-null   float64
#  8   Macro focus range        1037 non-null   float64
#  9   Storage included         1036 non-null   float64
#  10  Weight (inc. batteries)  1036 non-null   float64
#  11  Dimensions               1036 non-null   float64
#  12  Price                    1038 non-null   float64
# dtypes: float64(11), int64(1), object(1)
# ...

# %% [markdown]
# ## To print the statistical summary

# %%
df.describe()
# Out:
#        Release date  Max resolution  Low resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# count    1038.000000    1038.000000         1038.000000        1037.000000
# mean       32.963391     121.525048           44.145472           7.787850
# std        10.333149      93.455422           24.141959           8.100081
# ...

# %%
df.describe(include='all')
# Out:
#                   Model  Release date  Max resolution  Low resolution  \
# count              1038   1038.000000     1038.000000     1038.000000
# unique             1038           NaN             NaN             NaN
# top     Ricoh Caplio R6           NaN             NaN             NaN
# freq                  1           NaN             NaN             NaN
# mean                NaN   2003.590559     2474.672447     1773.936416
# std                 NaN      2.724755      759.513608      830.897955
# min                 NaN   1994.000000        0.000000        0.000000
# 25%                 NaN   2002.000000     2048.000000     1120.000000
# 50%                 NaN   2004.000000     2560.000000     2048.000000
# 75%                 NaN   2006.000000     3072.000000     2560.000000
# max                 NaN   2007.000000     5616.000000     4992.000000
#
#         Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# ...

# %% [markdown]
# ## To know if there is any duplicated sum

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## To count the number of categories

# %%
df['Model'].value_counts()
# Out:
# Ricoh Caplio R6                1
# Toshiba PDR-M60                1
# Pentax Optio T10               1
# Kodak Z700                     1
# Toshiba PDR-T10                1
#                               ..
# Nikon D2Xs                     1
# Casio Exilim EX-S500           1
# Fujifilm FinePix S5100 Zoom    1
# Olympus IR-300                 1
# Olympus C-5000 Zoom            1
# Name: Model, Length: 1038, dtype: int64

# %% [markdown]
# ## To display all records of Samsung Digimax 430.

# %%
samsung = df.loc[df['Model']=='Samsung Digimax 430']
samsung
# Out:
#                    Model  Release date  Max resolution  Low resolution  \
# 850  Samsung Digimax 430          2004          2272.0          2048.0
#
#      Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 850               3.0           35.0          114.0                80.0
#
#      Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# 850                5.0              32.0                    210.0       107.0
#
#      Price
# 850  229.0

# %% [markdown]
# ## Adding all the numeric values and storing in a new column. 'axis=1' means it will add the number row wise.

# %%
df.loc['Total'] = df.sum(numeric_only=True, axis=0)
df
# Out:
#                         Model  Release date  Max resolution  Low resolution  \
# 0            Agfa ePhoto 1280        1997.0          1024.0           640.0
# 1            Agfa ePhoto 1680        1998.0          1280.0           640.0
# 2            Agfa ePhoto CL18        2000.0           640.0             0.0
# 3            Agfa ePhoto CL30        1999.0          1152.0           640.0
# 4      Agfa ePhoto CL30 Clik!        1999.0          1152.0           640.0
# ...                       ...           ...             ...             ...
# 1034          Toshiba PDR-M70        2000.0          2048.0          1024.0
# 1035          Toshiba PDR-M71        2001.0          2048.0          1024.0
# 1036          Toshiba PDR-M81        2001.0          2400.0          1200.0
# 1037          Toshiba PDR-T10        2002.0          1600.0           800.0
# Total                     NaN     2079727.0       2568710.0       1841346.0
#
# ...

# %% [markdown]
# ## to find the specified row value with the using function iloc().

# %%
display(df.iloc[132])
# Out:
# Model                      Casio Exilim EX-V7
# Release date                           2007.0
# Max resolution                         3072.0
# Low resolution                         2560.0
# Effective pixels                          7.0
# Zoom wide (W)                            38.0
# Zoom tele (T)                           266.0
# Normal focus range                       30.0
# Macro focus range                        10.0
# Storage included                         11.0
# Weight (inc. batteries)                 190.0
# Dimensions                               96.0
# Price                                   299.0
# Name: 132, dtype: object

# %% [markdown]
# ## Median of all numeric columns

# %%
df.median()
# Out:
# Release date               2004.0
# Max resolution             2560.0
# Low resolution             2048.0
# Effective pixels              4.0
# Zoom wide (W)                36.0
# Zoom tele (T)               108.0
# Normal focus range           50.0
# Macro focus range             6.0
# Storage included             16.0
# Weight (inc. batteries)     226.0
# Dimensions                  101.0
# Price                       199.0
# dtype: float64

# %% [markdown]
# ## running .describe() on individual columns

# %%
df[["Model"]].describe()
# Out:
#                   Model
# count              1038
# unique             1038
# top     Ricoh Caplio R6
# freq                  1

# %% [markdown]
# ## Sorts the Price of Camera in Ascending Order

# %%
df.sort_values(by=["Price"])
# Out:
#                         Model  Release date  Max resolution  Low resolution  \
# 348              JVC GC-QX5HD        2001.0          2032.0          1024.0
# 347              JVC GC-QX3HD        2001.0          2032.0          1024.0
# 902                Sigma SD14        2006.0          2640.0          1776.0
# 903                 Sigma SD9        2002.0          2268.0          1134.0
# 1028           Toshiba PDR-M3        1999.0          1280.0           640.0
# ...                       ...           ...             ...             ...
# 834            Ricoh RDC-i500        2001.0          2048.0          1024.0
# 52              Canon EOS-1Ds        2002.0          4064.0          2032.0
# 53      Canon EOS-1Ds Mark II        2004.0          4992.0          3600.0
# 54     Canon EOS-1Ds Mark III        2007.0          5616.0          4992.0
# Total                     NaN     2079727.0       2568710.0       1841346.0
#
# ...

# %% [markdown]
# ## To bring up all the Unique models of Camera

# %%
df.Model.unique()
# Out:
# array(['Agfa ePhoto 1280', 'Agfa ePhoto 1680', 'Agfa ePhoto CL18', ...,
#        'Toshiba PDR-M81', 'Toshiba PDR-T10', nan], dtype=object)

# %% [markdown]
# # DATA VISUALIZATIONS

# %%
plt.figure(figsize=(10,5))

sns.barplot(df['Price'],df['Max resolution'],color='r',label=['Price','Max resolution'])
plt.xlabel('Price')
plt.ylabel('Max resolution')
plt.title('Line Chart', loc='center')
plt.legend()
plt.xticks(rotation=70)
plt.grid(True,color='grey')
plt.show()

# %% [markdown]
# ## Bar Plot showing which year has the highest camera release

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Release date', data=df, palette='coolwarm')
plt.show()

# %% [markdown]
# # Has there been an increase in Max Resolution over the years?

# %%
style.use('ggplot')

plt.figure(figsize=(10,5))
x = df['Release date']
y = df['Max resolution']

plt.scatter(x, y,color='#00A36C',marker='o',linewidths=1)
plt.title('Scatter Plot of Max Resolution over the year')
plt.grid(True, color='grey')
plt.show()

# %% [markdown]
# # Has there been a decrease in Low Resolution over the years?

# %%
style.use('ggplot')

plt.figure(figsize=(10,5))
x = df['Price']
y = df['Low resolution']

plt.scatter(x, y,color='#097969',marker='o',linewidths=1,s=100)
plt.title('Scatter Plot of Low Resolution over the years')
plt.grid(True,color='grey')
plt.show()

# %% [markdown]
# # Is there any relationship between Dimension and Year?

# %%
style.use('ggplot')

plt.figure(figsize=(10,5))
x = df['Release date']
y = df['Dimensions']

plt.scatter(x, y,color='none',edgecolor='#001187',s=200,marker='v',linewidths=0.5)
plt.title('Scatter Plot of Low Resolution over the years')
plt.grid(True,color='#AEAEAE')
plt.show()

# %%
storage = df['Price']
bins =[100,120,130,140,150,160,170,180,190,200]

plt.figure(figsize=(10,5))
plt.hist(storage,bins,histtype='stepfilled',color='#FF1B57',label=['Frequency','Storage Included'],alpha=1)
plt.title('Histogram Of Storage')
plt.xlabel('Storage')
plt.ylabel('Frequency')
plt.grid(True,color='#E0E0E0')
plt.legend()
plt.show()

# %% [markdown]
# ## To print the Datatypes and to know the Categorical variables

# %%
df.dtypes
# Out:
# Model                       object
# Release date               float64
# Max resolution             float64
# Low resolution             float64
# Effective pixels           float64
# Zoom wide (W)              float64
# Zoom tele (T)              float64
# Normal focus range         float64
# Macro focus range          float64
# Storage included           float64
# Weight (inc. batteries)    float64
# Dimensions                 float64
# Price                      float64
# dtype: object

# %% [markdown]
# # PAIR PLOT

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # VIOLIN PLOT

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["Dimensions"])

# %% [markdown]
# # RELATIONAL PLOT

# %%
# plt.figure(figsize=(10,9))
sns.relplot(x='Max resolution',y='Dimensions',color='yellow',hue='Price',data=df)
plt.show()

# %% [markdown]
# # HEATMAP

# %%
sns.set_theme()

plt.figure(figsize=(16,9))
sns.heatmap(df.corr(), annot=True, fmt=".2f")
plt.show()

# %% [raw]
# ============================================================================================================================
# ============================================================================================================================

# %% [markdown]
# # Conclusion: The Cameras with higher prices has more features in comparision with the cameras of lower prices and are more demand in public.
